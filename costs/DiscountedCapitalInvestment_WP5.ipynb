# %% [markdown]
# *Calculating the discounted capital cost for OSeMBE*
#
# Scenario: WP5 OPT-MIX

# %%
#Calculating the discounted capital cost for OSeMBE
#Scenario: WP5 OPT-MIX

import pandas as pd
import numpy as np
#DiscountedCapitalInvestment
# Removing indentation SHIFT+TAB
capcost = pd.read_csv(r"C:\Users\User\Documents\ECEMF_OSeMBE\input_data\WP5_OPT-MIX\data\CapitalCost.csv")
discount_factor = pd.read_excel('discount_rate_capital.xlsx')
newcap = pd.read_csv(r'C:\Users\User\Documents\ECEMF_OSeMBE\results\WP5_OPT-MIX\results_csv\NewCapacity.csv')
newcap['YEAR']=newcap['YEAR'].astype(int)

# Fixed cost + TotalCapacityAnnual
# Variable Operational cost = Variable + ProductionByTechnologyAnnual
#df_merge3 = df_merge1 + df_merge2

df_merge = pd.merge(capcost, newcap, on=['REGION', 'TECHNOLOGY', 'YEAR'])
df_merge['YEAR']=df_merge['YEAR'].astype(int)
df_merge = pd.merge(df_merge, discount_factor, on=['YEAR'])
#discount_factor
df_merge

#Hash out everything: CTRL+K+C
df_merge['VALUE_r'] = df_merge['VALUE_x'] * df_merge['VALUE_y'] * df_merge['VALUE'] 
df_merge['region'] = df_merge['TECHNOLOGY'].apply(lambda x: x[:2])
countries_mod = {'AT':'Austria','BE':'Belgium','BG':'Bulgaria','CH':'Switzerland','CY':'Cyrpus','CZ':'Czech Republic','DE':'Germany','DK':'Denmark','EE':'Estonia','ES':'Spain','FI':'Finland','FR':'France','GR':'Greece','HR':'Croatia','HU':'Hungary','IE':'Ireland','IT':'Italy','LT':'Lithuania','LU':'Luxembourg','LV':'Latvia','MT':'Malta','NL':'Netherlands','NO':'Norway','PL':'Poland','PT':'Portugal','RO':'Romania','SE':'Sweden','SI':'Slovenia','SK':'Slovakia','UK':'United Kingdom','EU28':'EU28'}
countrylist = []
for i in df_merge['region']:
    countrylist.append(countries_mod[i])

df_merge['Country'] = countrylist

table = pd.pivot_table(
            df_merge,
            index=["Country"],
            columns=["YEAR"],
            values=['VALUE_r'],
            aggfunc=np.sum,
        )

table.columns = table.columns.droplevel(0)
table.index.name = None
table.to_excel('DiscountedCapitalInvestment_WP5_OPT-MIX.xlsx')

# %% [markdown]
# Scenario: WP5 OPT-MIX-LimBio

# %%
#Calculating the discounted capital cost for OSeMBE
#Scenario: WP5-OPT-MIX

import pandas as pd
import numpy as np
#DiscountedCapitalInvestment
# Removing indentation SHIFT+TAB
capcost = pd.read_csv(r"C:\Users\User\Documents\ECEMF_OSeMBE\input_data\WP5_OPT-MIX-LimBio\data\CapitalCost.csv")
discount_factor = pd.read_excel('discount_rate_capital.xlsx')
newcap = pd.read_csv(r'C:\Users\User\Documents\ECEMF_OSeMBE\results\WP5_OPT-MIX-LimBio\results_csv\NewCapacity.csv')
newcap['YEAR']=newcap['YEAR'].astype(int)

# Fixed cost + TotalCapacityAnnual
# Variable Operational cost = Variable + ProductionByTechnologyAnnual
#df_merge3 = df_merge1 + df_merge2

df_merge = pd.merge(capcost, newcap, on=['REGION', 'TECHNOLOGY', 'YEAR'])
df_merge['YEAR']=df_merge['YEAR'].astype(int)
df_merge = pd.merge(df_merge, discount_factor, on=['YEAR'])
#discount_factor
df_merge

#Hash out everything: CTRL+K+C
df_merge['VALUE_r'] = df_merge['VALUE_x'] * df_merge['VALUE_y'] * df_merge['VALUE'] 
df_merge['region'] = df_merge['TECHNOLOGY'].apply(lambda x: x[:2])
countries_mod = {'AT':'Austria','BE':'Belgium','BG':'Bulgaria','CH':'Switzerland','CY':'Cyrpus','CZ':'Czech Republic','DE':'Germany','DK':'Denmark','EE':'Estonia','ES':'Spain','FI':'Finland','FR':'France','GR':'Greece','HR':'Croatia','HU':'Hungary','IE':'Ireland','IT':'Italy','LT':'Lithuania','LU':'Luxembourg','LV':'Latvia','MT':'Malta','NL':'Netherlands','NO':'Norway','PL':'Poland','PT':'Portugal','RO':'Romania','SE':'Sweden','SI':'Slovenia','SK':'Slovakia','UK':'United Kingdom','EU28':'EU28'}
countrylist = []
for i in df_merge['region']:
    countrylist.append(countries_mod[i])

df_merge['Country'] = countrylist

table = pd.pivot_table(
            df_merge,
            index=["Country"],
            columns=["YEAR"],
            values=['VALUE_r'],
            aggfunc=np.sum,
        )

table.columns = table.columns.droplevel(0)
table.index.name = None
table.to_excel('DiscountedCapitalInvestment_WP5_OPT-MIX_LimBio.xlsx')

# %% [markdown]
# Scenario: WP5 OPT-MIX-LimCCS

# %%
#Calculating the discounted capital cost for OSeMBE
#Scenario: WP5-OPT-MIX

import pandas as pd
import numpy as np
#DiscountedCapitalInvestment
# Removing indentation SHIFT+TAB
capcost = pd.read_csv(r"C:\Users\User\Documents\ECEMF_OSeMBE\input_data\WP5_OPT-MIX-LimCCS\data\CapitalCost.csv")
discount_factor = pd.read_excel('discount_rate_capital.xlsx')
newcap = pd.read_csv(r'C:\Users\User\Documents\ECEMF_OSeMBE\results\WP5_OPT-MIX-LimCCS\results_csv\NewCapacity.csv')
newcap['YEAR']=newcap['YEAR'].astype(int)

# Fixed cost + TotalCapacityAnnual
# Variable Operational cost = Variable + ProductionByTechnologyAnnual
#df_merge3 = df_merge1 + df_merge2

df_merge = pd.merge(capcost, newcap, on=['REGION', 'TECHNOLOGY', 'YEAR'])
df_merge['YEAR']=df_merge['YEAR'].astype(int)
df_merge = pd.merge(df_merge, discount_factor, on=['YEAR'])
#discount_factor
df_merge

#Hash out everything: CTRL+K+C
df_merge['VALUE_r'] = df_merge['VALUE_x'] * df_merge['VALUE_y'] * df_merge['VALUE'] 
df_merge['region'] = df_merge['TECHNOLOGY'].apply(lambda x: x[:2])
countries_mod = {'AT':'Austria','BE':'Belgium','BG':'Bulgaria','CH':'Switzerland','CY':'Cyrpus','CZ':'Czech Republic','DE':'Germany','DK':'Denmark','EE':'Estonia','ES':'Spain','FI':'Finland','FR':'France','GR':'Greece','HR':'Croatia','HU':'Hungary','IE':'Ireland','IT':'Italy','LT':'Lithuania','LU':'Luxembourg','LV':'Latvia','MT':'Malta','NL':'Netherlands','NO':'Norway','PL':'Poland','PT':'Portugal','RO':'Romania','SE':'Sweden','SI':'Slovenia','SK':'Slovakia','UK':'United Kingdom','EU28':'EU28'}
countrylist = []
for i in df_merge['region']:
    countrylist.append(countries_mod[i])

df_merge['Country'] = countrylist

table = pd.pivot_table(
            df_merge,
            index=["Country"],
            columns=["YEAR"],
            values=['VALUE_r'],
            aggfunc=np.sum,
        )

table.columns = table.columns.droplevel(0)
table.index.name = None
table.to_excel('DiscountedCapitalInvestment_WP5_OPT-MIX_LimCCS.xlsx')

# %% [markdown]
# Scenario: WP5 OPT-MIX-LimNuc

# %%
#Calculating the discounted capital cost for OSeMBE
#Scenario: WP5-OPT-MIX

import pandas as pd
import numpy as np
#DiscountedCapitalInvestment
# Removing indentation SHIFT+TAB
capcost = pd.read_csv(r"C:\Users\User\Documents\ECEMF_OSeMBE\input_data\WP5_OPT-MIX-LimNuc\data\CapitalCost.csv")
discount_factor = pd.read_excel('discount_rate_capital.xlsx')
newcap = pd.read_csv(r'C:\Users\User\Documents\ECEMF_OSeMBE\results\WP5_OPT-MIX-LimNuc\results_csv\NewCapacity.csv')
newcap['YEAR']=newcap['YEAR'].astype(int)

# Fixed cost + TotalCapacityAnnual
# Variable Operational cost = Variable + ProductionByTechnologyAnnual
#df_merge3 = df_merge1 + df_merge2

df_merge = pd.merge(capcost, newcap, on=['REGION', 'TECHNOLOGY', 'YEAR'])
df_merge['YEAR']=df_merge['YEAR'].astype(int)
df_merge = pd.merge(df_merge, discount_factor, on=['YEAR'])
#discount_factor
df_merge

#Hash out everything: CTRL+K+C
df_merge['VALUE_r'] = df_merge['VALUE_x'] * df_merge['VALUE_y'] * df_merge['VALUE'] 
df_merge['region'] = df_merge['TECHNOLOGY'].apply(lambda x: x[:2])
countries_mod = {'AT':'Austria','BE':'Belgium','BG':'Bulgaria','CH':'Switzerland','CY':'Cyrpus','CZ':'Czech Republic','DE':'Germany','DK':'Denmark','EE':'Estonia','ES':'Spain','FI':'Finland','FR':'France','GR':'Greece','HR':'Croatia','HU':'Hungary','IE':'Ireland','IT':'Italy','LT':'Lithuania','LU':'Luxembourg','LV':'Latvia','MT':'Malta','NL':'Netherlands','NO':'Norway','PL':'Poland','PT':'Portugal','RO':'Romania','SE':'Sweden','SI':'Slovenia','SK':'Slovakia','UK':'United Kingdom','EU28':'EU28'}
countrylist = []
for i in df_merge['region']:
    countrylist.append(countries_mod[i])

df_merge['Country'] = countrylist

table = pd.pivot_table(
            df_merge,
            index=["Country"],
            columns=["YEAR"],
            values=['VALUE_r'],
            aggfunc=np.sum,
        )

table.columns = table.columns.droplevel(0)
table.index.name = None
table.to_excel('DiscountedCapitalInvestment_WP5_OPT-MIX_LimNuc.xlsx')

# %% [markdown]
# Scenario: WP5 OPT-MIX-LimRES

# %%
#Calculating the discounted capital cost for OSeMBE
#Scenario: WP5-OPT-MIX

import pandas as pd
import numpy as np
#DiscountedCapitalInvestment
# Removing indentation SHIFT+TAB
capcost = pd.read_csv(r"C:\Users\User\Documents\ECEMF_OSeMBE\input_data\WP5_OPT-MIX-LimRES\data\CapitalCost.csv")
discount_factor = pd.read_excel('discount_rate_capital.xlsx')
newcap = pd.read_csv(r'C:\Users\User\Documents\ECEMF_OSeMBE\results\WP5_OPT-MIX-LimRES\results_csv\NewCapacity.csv')
newcap['YEAR']=newcap['YEAR'].astype(int)

# Fixed cost + TotalCapacityAnnual
# Variable Operational cost = Variable + ProductionByTechnologyAnnual
#df_merge3 = df_merge1 + df_merge2

df_merge = pd.merge(capcost, newcap, on=['REGION', 'TECHNOLOGY', 'YEAR'])
df_merge['YEAR']=df_merge['YEAR'].astype(int)
df_merge = pd.merge(df_merge, discount_factor, on=['YEAR'])
#discount_factor
df_merge

#Hash out everything: CTRL+K+C
df_merge['VALUE_r'] = df_merge['VALUE_x'] * df_merge['VALUE_y'] * df_merge['VALUE'] 
df_merge['region'] = df_merge['TECHNOLOGY'].apply(lambda x: x[:2])
countries_mod = {'AT':'Austria','BE':'Belgium','BG':'Bulgaria','CH':'Switzerland','CY':'Cyrpus','CZ':'Czech Republic','DE':'Germany','DK':'Denmark','EE':'Estonia','ES':'Spain','FI':'Finland','FR':'France','GR':'Greece','HR':'Croatia','HU':'Hungary','IE':'Ireland','IT':'Italy','LT':'Lithuania','LU':'Luxembourg','LV':'Latvia','MT':'Malta','NL':'Netherlands','NO':'Norway','PL':'Poland','PT':'Portugal','RO':'Romania','SE':'Sweden','SI':'Slovenia','SK':'Slovakia','UK':'United Kingdom','EU28':'EU28'}
countrylist = []
for i in df_merge['region']:
    countrylist.append(countries_mod[i])

df_merge['Country'] = countrylist

table = pd.pivot_table(
            df_merge,
            index=["Country"],
            columns=["YEAR"],
            values=['VALUE_r'],
            aggfunc=np.sum,
        )

table.columns = table.columns.droplevel(0)
table.index.name = None
table.to_excel('DiscountedCapitalInvestment_WP5_OPT-MIX_LimRES.xlsx')
